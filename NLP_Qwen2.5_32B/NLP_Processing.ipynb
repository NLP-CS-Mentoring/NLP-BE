# %% [markdown]
# # Qwen 32B Job Posting Cleaning
#
# This notebook records the offline preprocessing step used to clean OCR-heavy job posting text before embedding it into ChromaDB.
#
# Public portfolio version notes:
# - Personal Colab paths and execution outputs were removed.
# - Full crawled datasets are excluded from the repository.
# - Use `qwen_job_cleaner.py` for a reproducible script version.

# %%
import os

MODEL_ID = os.getenv("QWEN_MODEL_ID", "Qwen/Qwen2.5-32B-Instruct")
INPUT_FILE = os.getenv("JOB_POSTINGS_INPUT", "../samples/sample_job_postings.json")
OUTPUT_FILE = os.getenv("JOB_POSTINGS_OUTPUT", "../outputs/job_postings_cleaned_qwen32b.json")
BATCH_SIZE = int(os.getenv("QWEN_BATCH_SIZE", "4"))

print("Model:", MODEL_ID)
print("Input:", INPUT_FILE)
print("Output:", OUTPUT_FILE)

# %%
# Prefer the script version for actual execution:
#
# python NLP_Qwen2.5_32B/qwen_job_cleaner.py \
#   --model-id Qwen/Qwen2.5-32B-Instruct \
#   --input-file samples/sample_job_postings.json \
#   --output-file outputs/job_postings_cleaned_qwen32b.json \
#   --batch-size 4
